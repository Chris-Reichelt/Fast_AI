# %%
from fastai.tabular import *
import os

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#read in the csv data to be included in the dataset
data1 = pd.read_csv("^GSPC.csv") 
#correct data1's title to have DATE instead of Date
data1.columns=['DATE','Open', 'High','Low','Close','Adj Close','Volume'] #daily

data2 = pd.read_csv('10yr_tres_rate.csv') #daily
data3 = pd.read_csv('Fed_Funds_Rate.csv') #daily 2000-07-03 start date 
data4 = pd.read_csv('CPI_china.csv') #monthly
data5 = pd.read_csv('CPI_Germany.csv')#monthly
data6 = pd.read_csv('CPI_UK.csv')#monthly
data7 = pd.read_csv('CPI_US.csv')#monthly

data8 = pd.read_csv('Industrial_production.csv')#monthly
#correct the DATE format to yyyy-mm-dd
data8['DATE'] = pd.to_datetime(data8['DATE'])

data9 = pd.read_csv('UNRATE.csv')#monthly

df1=[data1,data2,data3] #daily info'd data
df2=[data4,data5,data6,data7,data9] #monthly info'd data
#change column titles to match others

data_day = reduce(lambda left,right: pd.merge(left,right,on='DATE'), df1)
data_mon = reduce(lambda left,right: pd.merge(left,right,on='DATE'), df2)


#data8.head()
#dataset[0:100]

# %%
data8['DATE']
#test=pd.merge(data7,data8, on='DATE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-0259b66321d3> in <module>()
# ----> 1 data8['DATE'].type
#       2 #test=pd.merge(data7,data8, on='DATE')
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
doc(pd.merge)
# Out:
# <h4 id="merge" class="doc_header"><code>merge</code><a class="source_link" data-toggle="collapse" data-target="#merge-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>merge</code>(<strong><code>left</code></strong>, <strong><code>right</code></strong>, <strong><code>how</code></strong>=<strong><em><code>'inner'</code></em></strong>, <strong><code>on</code></strong>=<strong><em><code>None</code></em></strong>, <strong><code>left_on</code></strong>=<strong><em><code>None</code></em></strong>, <strong><code>right_on</code></strong>=<strong><em><code>None</code></em></strong>, <strong><code>left_index</code></strong>=<strong><em><code>False</code></em></strong>, <strong><code>right_index</code></strong>=<strong><em><code>False</code></em></strong>, <strong><code>sort</code></strong>=<strong><em><code>False</code></em></strong>, <strong><code>suffixes</code></strong>=<strong><em><code>('_x', '_y')</code></em></strong>, <strong><code>copy</code></strong>=
# ...
