# %%
# !pip install textract
# Out:
# Collecting textract
#   Downloading https://files.pythonhosted.org/packages/32/31/ef9451e6e48a1a57e337c5f20d4ef58c1a13d91560d2574c738b1320bb8d/textract-1.6.3-py3-none-any.whl
# Requirement already satisfied: chardet==3.0.4 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from textract) (3.0.4)
# Collecting six==1.12.0
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting python-pptx==0.6.18
#   Downloading https://files.pythonhosted.org/packages/bf/86/eb979f7b0333ec769041aae36df8b9f1bd8bea5bbad44620663890dce561/python-pptx-0.6.18.tar.gz (8.9MB)
#      |████████████████████████████████| 8.9MB 37.0MB/s eta 0:00:01
# Collecting pdfminer.six==20181108
#   Downloading https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 37.4MB/s eta 0:00:01     |███████████████                 | 2.6MB 37.4MB/s eta 0:00:01
# Collecting EbookLib==0.17.1
#   Downloading https://files.pythonhosted.org/packages/00/38/7d6ab2e569a9165249619d73b7bc6be0e713a899a3bc2513814b6598a84c/EbookLib-0.17.1.tar.gz (111kB)
#      |████████████████████████████████| 112kB 50.5MB/s eta 0:00:01
# Collecting beautifulsoup4==4.8.0
#   Downloading https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 1.6MB/s eta 0:00:01
# Collecting argcomplete==1.10.0
#   Downloading https://files.pythonhosted.org/packages/4d/82/f44c9661e479207348a979b1f6f063625d11dc4ca6256af053719bbb0124/argcomplete-1.10.0-py2.py3-none-any.whl
# Collecting docx2txt==0.8
#   Downloading https://files.pythonhosted.org/packages/7d/7d/60ee3f2b16d9bfdfa72e8599470a2c1a5b759cb113c6fe1006be28359327/docx2txt-0.8.tar.gz
# Collecting extract-msg==0.23.1
#   Downloading https://files.pythonhosted.org/packages/a1/90/84485a914ed90adb5e87df17e626be04162fbba146dfecf34643659a4633/extract_msg-0.23.1-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 10.0MB/s eta 0:00:01
# Collecting xlrd==1.2.0
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 54.1MB/s eta 0:00:01
# Collecting SpeechRecognition==3.8.1
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
#      |████████████████████████████████| 32.8MB 21.9MB/s eta 0:00:01
# Requirement already satisfied: lxml>=3.1.0 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from python-pptx==0.6.18->textract) (4.2.1)
# Requirement already satisfied: Pillow>=3.3.2 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from python-pptx==0.6.18->textract) (5.2.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from python-pptx==0.6.18->textract) (1.0.4)
# Collecting pycryptodome
#   Downloading https://files.pythonhosted.org/packages/c1/f1/0ba99559391621280ce24adea245d31bf2eb2f20ac72270eead1813e8d2b/pycryptodome-3.9.0-cp36-cp36m-manylinux1_x86_64.whl (9.7MB)
#      |████████████████████████████████| 9.7MB 32.7MB/s eta 0:00:01
# Requirement already satisfied: sortedcontainers in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from pdfminer.six==20181108->textract) (1.5.10)
# Collecting soupsieve>=1.2
#   Downloading https://files.pythonhosted.org/packages/5d/42/d821581cf568e9b7dfc5b415aa61952b0f5e3dede4f3cbd650e3a1082992/soupsieve-1.9.4-py2.py3-none-any.whl
# Collecting tzlocal==1.5.1
#   Downloading https://files.pythonhosted.org/packages/cb/89/e3687d3ed99bc882793f82634e9824e62499fdfdc4b1ae39e211c5b05017/tzlocal-1.5.1.tar.gz
# Collecting olefile==0.46
#   Downloading https://files.pythonhosted.org/packages/34/81/e1ac43c6b45b4c5f8d9352396a14144bba52c8fec72a80f425f6a4d653ad/olefile-0.46.zip (112kB)
#      |████████████████████████████████| 112kB 51.1MB/s eta 0:00:01
# Collecting imapclient==2.1.0
#   Downloading https://files.pythonhosted.org/packages/dc/39/e1c2c2c6e2356ab6ea81fcfc0a74b044b311d6a91a45300811d9a6077ef7/IMAPClient-2.1.0-py2.py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 13.7MB/s eta 0:00:01
# Requirement already satisfied: pytz in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract) (2018.4)
# Building wheels for collected packages: python-pptx, EbookLib, docx2txt, tzlocal, olefile
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-cp36-none-any.whl size=274866 sha256=66b39e34f820672f4949090a709b0fdfe1022e5c03d4ed1bd8ace40b2056e59a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/1f/1f/2c/29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b
#   Building wheel for EbookLib (setup.py) ... done
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-cp36-none-any.whl size=25524 sha256=8a69740ac2055fc5e5362fb2f5ea5d7fcfda8ee45a2c47a734228730da188886
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/84/11/01/951369cbbf8f96878786a1f4da68bd7ac19a5d945b38e03d54
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp36-none-any.whl size=3144 sha256=6dbd7263f7887b5b353108ef1508597f66975d832c915ad3685be35878c107f1
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
#   Building wheel for tzlocal (setup.py) ... done
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-cp36-none-any.whl size=16731 sha256=d704632df6e9edf6f849264634cb3c93dc21fbd5a88093188c017efb48d97d5f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/15/ae/df/a67bf1ed84e9bf230187d36d8dcfd30072bea0236cb059ed91
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35424 sha256=e77a6a8ca1ed11f9a37c27f56c99a7d79de9657d7e16caecb471ae73c11e9850
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4b/f4/11/bc4166107c27f07fd7bba707ffcb439619197638a1ac986df3
# Successfully built python-pptx EbookLib docx2txt tzlocal olefile
# Installing collected packages: six, python-pptx, pycryptodome, pdfminer.six, EbookLib, soupsieve, beautifulsoup4, argcomplete, docx2txt, tzlocal, olefile, imapclient, extract-msg, xlrd, SpeechRecognition, textract
#   Found existing installation: six 1.11.0
#     Uninstalling six-1.11.0:
#       Successfully uninstalled six-1.11.0
#   Found existing installation: beautifulsoup4 4.6.0
#     Uninstalling beautifulsoup4-4.6.0:
#       Successfully uninstalled beautifulsoup4-4.6.0
#   Found existing installation: olefile 0.45.1
# ERROR: Cannot uninstall 'olefile'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !pip install textract --ignore-installed
# Out:
# Collecting textract
#   Using cached https://files.pythonhosted.org/packages/32/31/ef9451e6e48a1a57e337c5f20d4ef58c1a13d91560d2574c738b1320bb8d/textract-1.6.3-py3-none-any.whl
# Collecting extract-msg==0.23.1
#   Using cached https://files.pythonhosted.org/packages/a1/90/84485a914ed90adb5e87df17e626be04162fbba146dfecf34643659a4633/extract_msg-0.23.1-py2.py3-none-any.whl
# Collecting pdfminer.six==20181108
#   Using cached https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl
# Collecting SpeechRecognition==3.8.1
#   Using cached https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl
# Collecting six==1.12.0
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Processing /home/ec2-user/.cache/pip/wheels/1f/1f/2c/29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b/python_pptx-0.6.18-cp36-none-any.whl
# Collecting chardet==3.0.4
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Processing /home/ec2-user/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596/docx2txt-0.8-cp36-none-any.whl
# Collecting argcomplete==1.10.0
#   Using cached https://files.pythonhosted.org/packages/4d/82/f44c9661e479207348a979b1f6f063625d11dc4ca6256af053719bbb0124/argcomplete-1.10.0-py2.py3-none-any.whl
# Collecting xlrd==1.2.0
#   Using cached https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl
# Collecting beautifulsoup4==4.8.0
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Processing /home/ec2-user/.cache/pip/wheels/84/11/01/951369cbbf8f96878786a1f4da68bd7ac19a5d945b38e03d54/EbookLib-0.17.1-cp36-none-any.whl
# Processing /home/ec2-user/.cache/pip/wheels/15/ae/df/a67bf1ed84e9bf230187d36d8dcfd30072bea0236cb059ed91/tzlocal-1.5.1-cp36-none-any.whl
# Processing /home/ec2-user/.cache/pip/wheels/4b/f4/11/bc4166107c27f07fd7bba707ffcb439619197638a1ac986df3/olefile-0.46-py2.py3-none-any.whl
# Collecting imapclient==2.1.0
#   Using cached https://files.pythonhosted.org/packages/dc/39/e1c2c2c6e2356ab6ea81fcfc0a74b044b311d6a91a45300811d9a6077ef7/IMAPClient-2.1.0-py2.py3-none-any.whl
# Collecting sortedcontainers
#   Downloading https://files.pythonhosted.org/packages/13/f3/cf85f7c3a2dbd1a515d51e1f1676d971abe41bba6f4ab5443240d9a78e5b/sortedcontainers-2.1.0-py2.py3-none-any.whl
# Collecting pycryptodome
#   Using cached https://files.pythonhosted.org/packages/c1/f1/0ba99559391621280ce24adea245d31bf2eb2f20ac72270eead1813e8d2b/pycryptodome-3.9.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting lxml>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/ec/be/5ab8abdd8663c0386ec2dd595a5bc0e23330a0549b8a91e32f38c20845b6/lxml-4.4.1-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 49.9MB/s eta 0:00:01
# Collecting XlsxWriter>=0.5.7
#   Downloading https://files.pythonhosted.org/packages/25/88/a38f35b00ce4dd166a20e1a0a25e438e19e332e680df52af4aeac0df0f03/XlsxWriter-1.2.2-py2.py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 45.0MB/s eta 0:00:01
# Collecting Pillow>=3.3.2
#   Downloading https://files.pythonhosted.org/packages/10/5c/0e94e689de2476c4c5e644a3bd223a1c1b9e2bdb7c510191750be74fa786/Pillow-6.2.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 34.2MB/s eta 0:00:01
# Collecting soupsieve>=1.2
#   Using cached https://files.pythonhosted.org/packages/5d/42/d821581cf568e9b7dfc5b415aa61952b0f5e3dede4f3cbd650e3a1082992/soupsieve-1.9.4-py2.py3-none-any.whl
# Collecting pytz
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#      |████████████████████████████████| 512kB 43.6MB/s eta 0:00:01
# Installing collected packages: pytz, tzlocal, olefile, six, imapclient, extract-msg, sortedcontainers, pycryptodome, pdfminer.six, SpeechRecognition, lxml, XlsxWriter, Pillow, python-pptx, chardet, docx2txt, argcomplete, xlrd, soupsieve, beautifulsoup4, EbookLib, textract
# Successfully installed EbookLib-0.17.1 Pillow-6.2.1 SpeechRecognition-3.8.1 XlsxWriter-1.2.2 argcomplete-1.10.0 beautifulsoup4-4.8.0 chardet-3.0.4 docx2txt-0.8 extract-msg-0.23.1 imapclient-2.1.0 lxml-4.4.1 olefile-0.46 pdfminer.six-20181108 pycryptodome-3.9.0 python-pptx-0.6.18 pytz-2019.3 six-1.12.0 sortedcontainers-2.1.0 soupsieve-1.9.4 textract-1.6.3 tzlocal-1.5.1 xlrd-1.2.0

# %%
#this is a test program to extract text 
#from a PDF stored in the local dir

import PyPDF2
import textract

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
filename = 'enter the name of the file here' 
#open allows you to read the file
pdfFileObj = open(filename,'rb')
#The pdfReader variable is a readable object that will be parsed
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#discerning the number of pages will allow us to parse through all #the pages
num_pages = pdfReader.numPages
count = 0
text = ""
#The while loop will read each page
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
if text != "":
   text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
   text = textract.process(fileurl, method='tesseract', language='eng')
# Now we have a text variable which contains all the text derived #from our PDF file. Type print(text) to see what it contains. It #likely contains a lot of spaces, possibly junk such as '\n' etc.
# Now, we will clean our text variable, and return it as a list of keywords.
